# %% [markdown]
# <a href="https://colab.research.google.com/github/mshahzaib101/Text_Generation_With_LSTM/blob/master/Text_Generation_With_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow --upgrade
# Out:
# Collecting tensorflow
#   Downloading https://files.pythonhosted.org/packages/85/d4/c0cd1057b331bc38b65478302114194bd8e1b9c2bbc06e300935c0e93d90/tensorflow-2.1.0-cp36-cp36m-manylinux2010_x86_64.whl (421.8MB)
#      |████████████████████████████████| 421.8MB 38kB/s
# Requirement already satisfied, skipping upgrade: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.9.0)
# Requirement already satisfied, skipping upgrade: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.1.0)
# Requirement already satisfied, skipping upgrade: gast==0.2.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.2.2)
# Requirement already satisfied, skipping upgrade: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.1.8)
# Requirement already satisfied, skipping upgrade: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.8.1)
# Collecting tensorboard<2.2.0,>=2.1.0
#   Downloading https://files.pythonhosted.org/packages/d9/41/bbf49b61370e4f4d245d4c6051dfb6db80cec672605c91b1652ac8cc3d38/tensorboard-2.1.1-py3-none-any.whl (3.8MB)
#      |████████████████████████████████| 3.9MB 51.4MB/s
# Requirement already satisfied, skipping upgrade: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (3.2.0)
# Requirement already satisfied, skipping upgrade: six>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.12.0)
# Requirement already satisfied, skipping upgrade: keras-preprocessing>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.1.0)
# Collecting tensorflow-estimator<2.2.0,>=2.1.0rc0
#   Downloading https://files.pythonhosted.org/packages/18/90/b77c328a1304437ab1310b463e533fa7689f4bfc41549593056d812fab8e/tensorflow_estimator-2.1.0-py2.py3-none-any.whl (448kB)
#      |████████████████████████████████| 450kB 47.3MB/s
# Requirement already satisfied, skipping upgrade: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.24.3)
# Requirement already satisfied, skipping upgrade: scipy==1.4.1; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.4.1)
# Requirement already satisfied, skipping upgrade: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.12.1)
# Requirement already satisfied, skipping upgrade: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.0.8)
# Requirement already satisfied, skipping upgrade: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (3.10.0)
# Requirement already satisfied, skipping upgrade: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.34.2)
# Requirement already satisfied, skipping upgrade: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.18.1)
# Requirement already satisfied, skipping upgrade: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow) (1.0.0)
# Requirement already satisfied, skipping upgrade: requests<3,>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow) (2.21.0)
# Requirement already satisfied, skipping upgrade: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow) (0.4.1)
# Requirement already satisfied, skipping upgrade: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow) (1.7.2)
# Requirement already satisfied, skipping upgrade: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow) (45.2.0)
# Requirement already satisfied, skipping upgrade: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow) (3.2.1)
# Requirement already satisfied, skipping upgrade: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow) (2.8.0)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow) (2.8)
# Requirement already satisfied, skipping upgrade: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow) (1.24.3)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow) (2019.11.28)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow) (3.0.4)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.2.0,>=2.1.0->tensorflow) (1.3.0)
# Requirement already satisfied, skipping upgrade: rsa<4.1,>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow) (4.0)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow) (0.2.8)
# Requirement already satisfied, skipping upgrade: cachetools<3.2,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow) (3.1.1)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.2.0,>=2.1.0->tensorflow) (3.1.0)
# Requirement already satisfied, skipping upgrade: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<4.1,>=3.1.4->google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow) (0.4.8)
# ERROR: tensorflow-federated 0.12.0 has requirement tensorflow-addons~=0.7.0, but you'll have tensorflow-addons 0.8.3 which is incompatible.
# Installing collected packages: tensorboard, tensorflow-estimator, tensorflow
#   Found existing installation: tensorboard 1.15.0
#     Uninstalling tensorboard-1.15.0:
#       Successfully uninstalled tensorboard-1.15.0
#   Found existing installation: tensorflow-estimator 1.15.1
#     Uninstalling tensorflow-estimator-1.15.1:
#       Successfully uninstalled tensorflow-estimator-1.15.1
#   Found existing installation: tensorflow 1.15.0
#     Uninstalling tensorflow-1.15.0:
#       Successfully uninstalled tensorflow-1.15.0
# Successfully installed tensorboard-2.1.1 tensorflow-2.1.0 tensorflow-estimator-2.1.0

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.1.0'

# %% [markdown]
# # Text generation with LSTM
#
# This notebook contains the code samples found in Chapter 8, Section 1 of [Deep Learning with Python](https://www.manning.com/books/deep-learning-with-python?a_aid=keras&a_bid=76564dff). Note that the original text features far more content, in particular further explanations and figures: in this notebook, you will only find source code and related comments.
#
# ----
#
# [...]
#
# ## Implementing character-level LSTM text generation
#
#
# Let's put these ideas in practice in a Keras implementation. The first thing we need is a lot of text data that we can use to learn a
# language model. You could use any sufficiently large text file or set of text files -- Wikipedia, the Lord of the Rings, etc. In this
# example we will use some of the writings of Nietzsche, the late-19th century German philosopher (translated to English). The language model
# we will learn will thus be specifically a model of Nietzsche's writing style and topics of choice, rather than a more generic model of the
# English language.

# %% [markdown]
# ## Preparing the data
#
# Let's start by downloading the corpus and converting it to lowercase:

# %%
import tensorflow.keras
import numpy as np

path = tensorflow.keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 0s 0us/step
# Corpus length: 600893

# %% [markdown]
# Next, we will extract partially-overlapping sequences of length `maxlen`, one-hot encode them and pack them in a 3D Numpy array `x` of
# shape `(sequences, maxlen, unique_characters)`. Simultaneously, we prepare a array `y` containing the corresponding targets: the one-hot
# encoded characters that come right after each extracted sequence.

# %%
# Length of extracted character sequences
maxlen = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200278
# Unique characters: 57
# Vectorization...

# %% [markdown]
# ## Building the network
#
# Our network is a single `LSTM` layer followed by a `Dense` classifier and softmax over all possible characters. But let us note that
# recurrent neural networks are not the only way to do sequence data generation; 1D convnets also have proven extremely successful at it in
# recent times.

# %%
from tensorflow.keras import layers

model = tensorflow.keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %% [markdown]
# Since our targets are one-hot encoded, we will use `categorical_crossentropy` as the loss to train the model:

# %%
optimizer = tensorflow.keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# ## Training the language model and sampling from it
#
#
# Given a trained model and a seed text snippet, we generate new text by repeatedly:
#
# * 1) Drawing from the model a probability distribution over the next character given the text available so far
# * 2) Reweighting the distribution to a certain "temperature"
# * 3) Sampling the next character at random according to the reweighted distribution
# * 4) Adding the new character at the end of the available text
#
# This is the code we use to reweight the original probability distribution coming out of the model,
# and draw a character index from it (the "sampling function"):

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# Finally, this is the loop where we repeatedly train and generated text. We start generating text using a range of different temperatures
# after every epoch. This allows us to see how the generated text evolves as the model starts converging, as well as the impact of
# temperature in the sampling strategy.

# %%
import random
import sys

for epoch in range(1, 60):
    print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
              batch_size=128,
              epochs=1)

    # Select a text seed at random
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')

    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)

        # We generate 400 characters
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# Train on 200278 samples
# 200278/200278 [==============================] - 312s 2ms/sample - loss: 1.9640
# --- Generating with seed: "be no falling into unjust scornfulness. the injustice in
# sla"
# ------ temperature: 0.2
# be no falling into unjust scornfulness. the injustice in
# slater and profound and proto it is a such personal the lother to the spirit and profound of the such self the moral the farther the present of the ferent of the more one of the moral the moral the morality of the lother of the religious profound of the morality of the morality of the every has the moral the morality and compority of the such places of the sporing of the moral the present of the reli
# ------ temperature: 0.5
# h places of the sporing of the moral the present of the religious longing to be sume and so the suffer such son the more it waster and exaction, in the personable to the stand of the moral it is a formang and responding
# the hister, and so from the morality and villes who a mether prodsiries so longer sead the higher of a seater and perious to result of becomed of the profeminations of the morality and refarien and so spirit which who gonal man maning of th
# ------ temperature: 1.0
#  and refarien and so spirit which who gonal man maning of the moitponion statted of theritese and know here, and
# let
# myories of propersap and
# ontady as stwill "more must of mors relactely, them is ankworld only be
# right he moxitatherstand that itself wesite. and living thew. purises the ont oppelain" the "man and instw still one rovele2s a fould anfurem progessine, and who bring
# with
# sidigict on bring as
# differan insither does as u greants differentkex" so
# ------ temperature: 1.2
# ring as
# differan insither does as u greants differentkex" so lamer. hitherto mourlabority,"--onem, they,"
# an, all the
# bas2.---and words thinh! in samkbver slot this ortinn? is  or wolls" toorfortred that which haval on covers
# ayvent only or sutaps gentative bey henders,s, having
# and scay mortaring of this
# a mnew. yverselves goed os a chlompancies! arties
# have of their tacaycy? socien on "rew,eld, hoor (lof musr -belo, and nagurations of the one'cation, and
# epoch 2
# Train on 200278 samples
# 200278/200278 [==============================] - 311s 2ms/sample - loss: 1.6153
# --- Generating with seed: "siness of the very few to be independent; it is a
# privilege "
# ------ temperature: 0.2
# siness of the very few to be independent; it is a
# privilege and something the strength and even in the strong the most the most the most and in the spirit is all the father and metaphysic of the present and desire and and strong and in the sense the metaphysical pain and the proper--in the spirit and such and the most and the most the metaphysical and and former and and of the strength and and and the most and and and and and strength and with the most be
# ------ temperature: 0.5
#  the most and and and and and strength and with the most be most are still them decise the efficter and for the concerning the consemply and with the interpous the reare historics, to a propersificude man, a pates and put and say, they of the posis as a postigned purities and sufficiends and reverety and restraig and reserved and were so the proved in the world so rentrestic of the most great the man. the comes and intellect of the even in the most the mos
# ------ temperature: 1.0
# man. the comes and intellect of the even in the most the most it. a cread well develoom morald which say it is
# then i is it in a givisbity ears sciench, and in out of natural or wased been genest corvent be
# all
# to whol yor the hather for he laterics. i
# betinct him in need each.=--they relies and once so knows all tority and allor . sylove a thing
# to general case trongur "le vantable your avould last to
# mechination, it a nim, has growing or dancer has are
# ------ temperature: 1.2
# ast to
# mechination, it a nim, has growing or dancer has are not. the "musip; in agree or anothings lare made a comed to seeishine ty exambordness, : heiver the bedin, or, it be lang melan. that theme wheregerady pie with ucan his thingsl
# affeass, it netersk of bity. but they
# epposities
# precourse, by serving.ute by vain-: anftrematery, courcerusk. it, as only misundief nueps--it on notivation
# evencupiliting and tumpen time. but bu more eningtain
# struefe. "t
# epoch 3
# Train on 200278 samples
# 200278/200278 [==============================] - 312s 2ms/sample - loss: 1.5279
# --- Generating with seed: "re tedious, one
# cannot think highly enough of their utility."
# ------ temperature: 0.2
# re tedious, one
# cannot think highly enough of their utility. the in the still one of a subtle the the profounded the profoundes of the enough the profounde of the proposition of the the moral things the things and all the still the profounded the most one who has the and the world that the man and so the the things of the most the most the strengthess of the the profounded the most the profounded the most the proper of the respect to the most the sumber an
# ------ temperature: 0.5
# the most the proper of the respect to the most the sumber and better, have no now the most the wart dit so to the "greater of the concerning the other thinking the experience the man in the religious profounded when the strengtht them
# out thinking the last the
# edurage in a
# soce his experience of the art of the profounded a stach of the sumbacity and and light and hand of his own the whole desire
# and history of the agand and the most and schopless of the ex
# ------ temperature: 1.0
# nd history of the agand and the most and schopless of the expressions to stance, they delught, often oo  that conceds.
#
#  guldingsly and differses. a mat know (an in its dinglarnations
# sympathy of themsive thishys and schiperfuls to suffer that and rerec tame the
# ort peruaitent questions
# and ne: all free opposing theve in
# o; the
# bad in the minstion,
# it i
# rewards onoether natural, desirt and or nature be in
# the whatest find at according in theim of the valus
# ------ temperature: 1.2
# re be in
# the whatest find at according in theim of the valus it civilizary to holm
# a durctied "just
# and
# sympave canlof
# instainen: communifiver yers? every one of our wart, sympateoy of avolouely thinking free-chadaring or no shiate eningaking than cathirging and evaur. if-is, is not compantwith thoused, nameffutity.
#
# meling accanter, in aditaticately,
# from emrance to culte's among materiges: on otherbisured,
# virtuh.ly, feellokk of many.y
# nlacking, and mang
# epoch 4
# Train on 200278 samples
# 200278/200278 [==============================] - 311s 2ms/sample - loss: 1.4800
# --- Generating with seed: "ing in many ways
# to see whether the genius for money and pat"
# ------ temperature: 0.2
# ing in many ways
# to see whether the genius for money and pate of the most standard and such a such a such a stand it is the most man of the stand of the strength and the matter of the strength and the standard that is all it is man and in the standaris of the strength and of the most stand in the contrary and it is the strength and man and and strove the strength and man is the man of the strong that the strength and such a such a superite and the person o
# ------ temperature: 0.5
# hat the strength and such a such a superite and the person of the life as the reperrenting is a restences to himself and something and the man as the stand also philosophic world to command than the really of his other once as he will master" and compulsess in the tastes as the masters why shall of the strong the personal compulses and of his the present characters than it is most worth and a conduct, a         "destinication of the communitors of the powe
# ------ temperature: 1.0
# uct, a         "destinication of the communitors of the power, with esonever! if the pertaike of men so painous the
# here, therefore is allow them as wor the ferreal manifeluld at the world, under the stephal-, if madager and canclited a stall wart
# worth it prosuftics of any =aurtimatation: the pain prasibates revell! among dis obtain sevirtselind, wishes as an parted. with "it has namulomes, first of t christion, set symplath percestral
# being us to the mak
# ------ temperature: 1.2
#  of t christion, set symplath percestral
# being us to the makes with
# iglemishing all bring and
# "a mo, would alone enrither to long-kness the huping without pusshary to
# musr.
# she knowledge
# over is everef it is possese ame in has sere fable at promuded that rumint of evirtre! like the perieders--from the s=, it is stepply as presuppible as owing it.--saigxtrfienth, worthing i another otherlre questable, his cribling. all, religeous matiwial cyarsely "individu
# epoch 5
# Train on 200278 samples
# 200278/200278 [==============================] - 311s 2ms/sample - loss: 1.4497
# --- Generating with seed: "out myself. there must be a sort of repugnance
# in me to beli"
# ------ temperature: 0.2
# out myself. there must be a sort of repugnance
# in me to believes the strong the discoveres which has a something in the stronger of the sense of the still all the stronger of the strong the stand of the strong the sense of the sense of the still as the stand of the stronger the stronger of the sense of the soul and the stranges and the strong the strong the sense of the strong the strong and so the sense of the still and something and so the stronger of th
# ------ temperature: 0.5
# e sense of the still and something and so the stronger of the ferther of the something which a merous.
#
# chilobice the places and dangerous oping as the consequence and soul and more superficial and conscience of strength, the stone the soul, and be the mother will no longer and by strong life the world, as other will the more and the believe he was as a man sere of perhaps it has aboutely regard the soul and inducest the contradict the "good does not it ma
# ------ temperature: 1.0
# he soul and inducest the contradict the "good does not it may be among beout "shiping detting those towards of the strong for ous indendwed, his comprhmarily
# look him food something in in; a
# this seeity of present of his
# in decimpated,
# sense periods
# will be difference--the more mosting all from says. dindadious standard of divin envan the the (asough first that a wanting of things. it is libery for whih need who his man noulatic and grfue
# metaphysic breave
# ------ temperature: 1.2
# r whih need who his man noulatic and grfue
# metaphysic breaved of s of high. for this hi spirit,"
#  to
# also selve, "gooder
# oansgivacy and
# did not coputady.xthing of
# disp. bycioms original-doubt cogmmdrem, of art of pastives
# only their brlood despaved yet
# neferther. nation from knowledge
# and subjects of
# the can uprarked overans nothutical, it, finimness," philosophicn, acts of science, and
# to (that, laugh, literaass, to the thing!
# god.=--mans
# wele like.
# "for
# epoch 6
# Train on 200278 samples
# 200278/200278 [==============================] - 311s 2ms/sample - loss: 1.4269
# --- Generating with seed: "erful, perilous
# leap,--something that should be advised agai"
# ------ temperature: 0.2
# erful, perilous
# leap,--something that should be advised against the same the sense of the subjection of the soul is the subjection of the subtle of the subtle the subjection of the prompted to the state the soul is the world and the subtle of the sense of the sense of the soul of the soul is the subjection of the sense of the soul is a soul is the soul of the present and soul is the conscience of the happiness of the state the subjection of the subtle the
# ------ temperature: 0.5
# the happiness of the state the subjection of the subtle the friendsh, seem that we is always the the same such a some something who who seed man interpretation the active prompted as a new deeper and means of life of the senderest, the prompt of history. it is always for the preductively has the sense of the sort of subjection to the reality to the world in the god to look and refentithed the soul and such and more for the philosophers--in something in the
# ------ temperature: 1.0
#  and such and more for the philosophers--in something in the valulvation
# degreshing in stwonctial palkming preisings to morally with as  readew
# democrty, long and which spiritually, poin he steir only to rear
# above refined superati mattering according,
# liber tho oping to best really coalsh--in
# the very weep instincts hable determons
# of pitery i that pure suffering, their
# taste meett--in the beneorment of ast doingled
# world a soulness. and with wompe develo
# ------ temperature: 1.2
# ment of ast doingled
# world a soulness. and with wompe develops eneitful,
# nop," ivuols to pasied rempt to the ascertain benefolyh inwampimence,
# itwocham. themate to disdisse defen to m; in the from the end woman in european generation of alfart.
# ibque the pride with woman withingwing concernive fathered, a depty to beruth, pirto's it were art; bareuded alweefeity,-noin unkins of lieb than utulac thing anli, to cause. nwar. i "doling.
# heneger it man co lonem
# epoch 7
# Train on 200278 samples
# 200278/200278 [==============================] - 312s 2ms/sample - loss: 1.4120
# --- Generating with seed: "ually grow weaker under
# the influence of purifying knowledge"
# ------ temperature: 0.2
# ually grow weaker under
# the influence of purifying knowledge to the stronger to the stronger and the stronger of the standard to a deceive of the standard the same to the stronger of saint to be all the stronger and the spiritual and the spiritual spiritual and the stronger to the standard of the stronger of the spiritually and the stronger and the spiritual and the stronger and disposition of the strange of the standard of the stronger in the stronger of
# ------ temperature: 0.5
#  strange of the standard of the stronger in the stronger of a time and a domatic of the suitered by the same
# long and serious has for the same as it is man is every fool of the feelings of new have also a spiritial and the historical and in the even and the form what the metaphysical instincts of moralistic and all the sariful in the profitence to the conception of the stronger of himself in it, and man and consequently to be to the salver and the demands
# ------ temperature: 1.0
# nd man and consequently to be to the salver and the demands his may
# no warps mind and are mistaken of cleass;--wheneveresten the same soperet, que to fative conser'efine and wormates himself of right into qualous standay is all the weswerints, grantidy people. in
# all exure at many it be
# highed as a domany and ungingury hitherto foo a coantr--accounts asselting ceptity. it the stront and adcicle-accommands and allousially manners consists gradited to get h
# ------ temperature: 1.2
# ccommands and allousially manners consists gradited to get hind one will, matter, as to pevple? it is celleds of garmately one evinficalt. repumpansing of "ethits gale embrosed itlein noilogrty forker.
# the either, not for ye parientness. and win race soully but i going cincunity of ,ully.=--metaphysical
# jespiration
# which henes and end and action
# the eus aware, to long, and holdwithere as event"wisb the taccal. beinesse
# is time on an eal that "such that of
# epoch 8
# Train on 200278 samples
# 200278/200278 [==============================] - 310s 2ms/sample - loss: 1.3962
# --- Generating with seed: "f necessity. all is guiltlessness, and knowledge is the way "
# ------ temperature: 0.2
# f necessity. all is guiltlessness, and knowledge is the way the promise of the man is a such and a suffers the promiced and in the stand of the state of the state of the stand of the standard to the stand of the promise the senses and a man and a proved to the stand of the stand of the stand of the senses of the stree the power and soul of the stand of the state of the state of the conscience of the stand of the state of the stand of the standard and all t
# ------ temperature: 0.5
# he stand of the state of the stand of the standard and all the sense of the senses in the stree knowledge of so self-contrary even a philosopher of the more thing in the sense and man of the sense of our no conscience itself of the world the mans
# and philosopher and man is morality of the stand and put the subtle his spirit is the takes of the spring to the being of a discovered that the spand when a conscience, as the sense, who seems and of the sense to
# ------ temperature: 1.0
# n a conscience, as the sense, who seems and of the sense to its men of from
# christianity.
#
# 1loon of all in, should a smitn beyond cheired, as the unroise
# be conscience, hypothety, wherefore centive of the masters socie, for to error are you plwadomend revenge, which because
# less siefucity were
# they enlments, as lave magicles of example over tart of envorard? or to for the name
# cheilesses all "obucarly losips but adwardman attained, in he was right"--religi
# ------ temperature: 1.2
# arly losips but adwardman attained, in he was right"--religions should "becimerisws of the
# spirits ethic moniey
# disconarly accor of self. aldicatur non"red or conduct its soulse .
#
#
# c2on barong:
#    know. the oc" privitio
# rejects
# a china, this thole; askincswjud to different existe, which may "makes virtues, even gooly,
# he for diff ever atawvarly has morawing, and amonre: as he herise is belle of life for dwelley sous handf arsul he is a impresibel
# to they
# epoch 9
# Train on 200278 samples
# 200278/200278 [==============================] - 310s 2ms/sample - loss: 1.3833
# --- Generating with seed: ", even under the guise of science, about coming conditions o"
# ------ temperature: 0.2
# , even under the guise of science, about coming conditions of the fact of the same and soul--and of the world and the suffering and suffering of the suffering of the subjection of the sense of the subjection of the more supereating and instinct of the fact of the end and soul--and also an antight to the sense of the conscience and self-and the spirit is to the same and soul--and is the suffering and such a thing of the soul, and the same and productive of
# ------ temperature: 0.5
# nd such a thing of the soul, and the same and productive of the father such a higher life as a consequently, in a god that will their weaker and for the masters--in the last the superis personal devilide, the science of
# the strength of many soul, he may be distinguishers of the mastering of the subjection of the subjection of the skepticism which short: the stronger and the fore his own will to invention is to an even that a things, whereos a contemnarian
# ------ temperature: 1.0
# vention is to an even that a things, whereos a contemnarian frimpricisted, holgstked, hages no present different--which is greating evency good of the very
# ; all opinions of the task aadd and soupph.
# endowing like the
# -must have always moranfe, as mediocroming enverance, a history, the phinomy that diffiriis man noilds--and account and question in it to philosophical history, and superfigion om self-regards and freatived the fact becomes and as its interis
# ------ temperature: 1.2
# lf-regards and freatived the fact becomes and as its interisming  fully good"--suffercoles; the type vitowing learniund struggh. this discopernading hinkne, his, should not, one offorgeor,
# what hear free, and derived that is assument--asimstants will reflects.--nolews the
# entigulally farfle, the precisely, whensiseff "history.ful grounder earer
# neces, of "morey, to so euretaheness. whereferen or else yet very dangeration and dea nowada,es bet(nifice evenfu
# epoch 10
# Train on 200278 samples
# 200278/200278 [==============================] - 310s 2ms/sample - loss: 1.3732
# --- Generating with seed: "the testimony of pleasure (or as the church says, the eviden"
# ------ temperature: 0.2
# the testimony of pleasure (or as the church says, the evidence of the same the strength of the same think and the spiritual soul of the same the strunguagily in the sense of the same the states of the states of the same the same the most because there is the states and the sense of the same the sense of the sense and deception of the states of the most sense and super-the still a consequance to the states and soul of the science of the sense of the states
# ------ temperature: 0.5
# e states and soul of the science of the sense of the states to the tasted a thing and the way for the senses of the way at all they are in the rests and such a thing of their thing and his friend and sense to the most a fines to the most souloness of his soul and man and the most propress is most supposing the first conceand at the sense,
# "to his insuperience
# from the will to see concernive himself and developing for the becomse--acts in the fation to the
# ------ temperature: 1.0
# f and developing for the becomse--acts in the fation to the "good
# stand anough
# knowe the satoriality, from the antisuc disages of the
# consequance this isselves obliged live-aplect how is in the child bernegned! hand, he erroring lives sels.
#
# 121. he has been itters of anything man a costepted; grands
# eas nimally bor do
# not personels actual sense, wishes to which was petted: florin vulgaristic, science of rich, attain utilitymed
# question of all thereby of s
# ------ temperature: 1.2
# ence of rich, attain utilitymed
# question of all thereby of seff that thor? it is yesvible? why lioks
# a blence of first for the dangerous!
#
# 62. in
# agait which nowerrobutity has been first element and varie man.
# thergourses, an astolless," amouther dexilical exchirage from achoventure but the cengurve ssistated--is a thing to
# levit as
# of thinks"--in
# all atgelsion is
# prooude.! first prevaisly, are framed hes, in himself to mast let himself nowadaved the vict.
# epoch 11
# Train on 200278 samples
# 200278/200278 [==============================] - 309s 2ms/sample - loss: 1.3654
# --- Generating with seed: ", the great
# majority of mankind endure life without any grea"
# ------ temperature: 0.2
# , the great
# majority of mankind endure life without any great spirit of which the more of the states and common to the sense of the spirit is the spirit and soul--it is not the states to the sense of the sense to the sense of the spirit of the sense of the sense of the consciously and the strong to the spirit and souls of the superiorities and served to be souls of the greatest and deception and the sense of the sense of the states and soul of the same and
# ------ temperature: 0.5
# he sense of the sense of the states and soul of the same and around the stomists of the depres who has would not not only one can be taste, it is all its religions of the sensation of the same the more more experience is it is the states a significance of the bad to have to grand at the realing to the forer proper and remains of the delusion, who has to are according to the sense to really depression of the same soul of the strangers. to be advantial taste
# ------ temperature: 1.0
# ion of the same soul of the strangers. to be advantial taste lfwer estance of mann homestion this any following introsoun
# and a systerism of ut-dox a
# soulsh,
# it amagrad
# in namely, but comes the te"fically become kinds.--these and things.
#
#
# 1ent domine deuply uall's it is name, as hangantary is art, to cataking everytsing
# former of all the true progress
# and asked, foundic work,--we must the leads is nepract! but tere understand that you are be his read inse
# ------ temperature: 1.2
# s nepract! but tere understand that you are be his read insefrence and life--though it is o"--who -wemanstoue now; would bood no distepwith absunder.itible, as untorol!
# "hegenation, mochiety, why is there not long belong iorating mereness" and woman restred. such quinlquently burcle--e causuous, that men
# them,
# and mode of their molome,
# these has have
# co
# spirit "europe, only
#        quiol antiquity-moral ear no co
# scymkes is alcround yen to lone;
# mole or meo
# epoch 12
# Train on 200278 samples
# 200278/200278 [==============================] - 309s 2ms/sample - loss: 1.3565
# --- Generating with seed: "elight in
# self-control are on the increase. to them religion"
# ------ temperature: 0.2
# elight in
# self-control are on the increase. to them religion to the superstilly to be such a superiority of the superstitious and sense of the superstitious and the supertion of the complete and the sense of the sense of the superstitious and such a man with the most perhaps a superior and the sense of the deception of the predised to be a superiort and the such allow the superstitious the superstitious and superiority of the superstitious and such a super
# ------ temperature: 0.5
# itious and superiority of the superstitious and such a superiorical more man is the sense of the self as its only the most the delight its to all it is the restrically disersses the commanded the taste and the things seems the more literated of predised believes the expedients, we have a soul distinguisher the philosophers, and it was he has not men the complete, as the conduct that it is not one is falsehes to consequently is be hattle entires our subtlet
# ------ temperature: 1.0
# is falsehes to consequently is be hattle entires our subtlety--"which
# partt bringered
# own the error themselves first also perhaps be causad time is despect; it was generates. one is a back"'s form
# of adrogate me thinkings mentatiously, itself to do orsen as to time singless such them, where however? it pernate about figual oth evilcagen ! he who huse butgesh the dark--ylive "galk out will or no arp (ethics of the empratued to gets is must
# be rate of dingly
# ------ temperature: 1.2
# p (ethics of the empratued to gets is must
# be rate of dingly badman and reason all
# s of means that the preciepsially redous humanity perhaps: any, also. when every naduced, human self does; on science, in the vengearly here experience, noismum and without more faculty of meduos.--gratixitul begond overyterness is to could so good, evescomens, the comprterful human actually great such a soul. freely antifica, now the riarituple of domany, freedom anything b
# epoch 13
# Train on 200278 samples
# 200278/200278 [==============================] - 307s 2ms/sample - loss: 1.3503
# --- Generating with seed: "st extensive perspectives for god; on that
# account he keeps "
# ------ temperature: 0.2
# st extensive perspectives for god; on that
# account he keeps for the more soul of the belief to the general and subtly and say that the proper of the belief the sense of the more more from the more proper of the more superiority of the same them to have not be as the sense of the proper for the general and something in the same and the subtles and more from the same and more will to the more superior and such a sublimed, the more superiority of the same and
# ------ temperature: 0.5
# or and such a sublimed, the more superiority of the same and say can a matter of the propers and cause to understand with the hardent inmenions to the there takes or the entity--he will beside the right to with the best see of the great great god, and old pressing are fal such an of the present one any mediocre--and all themselves. it is the say some soul of the powerful and acts as a hypotheses of success, or an amely are significance of the instinct of t
# ------ temperature: 1.0
# f success, or an amely are significance of the instinct of themselves by barniness, one; there him       pilow event that muse die "force alloogne
# indeen, unwitedeh
# pet no demand example
# sick and sty, and a roman of man creed him who is thore will such external, upon indicided for how will but from philosopher but he selmigt of this shifucticted as repleced german sort of which sympathy, and soul and instinct--of the gets that they cerious, beyth are mersl
# ------ temperature: 1.2
# and instinct--of the gets that they cerious, beyth are mersline us look--logis, good thing haviwing soulfment, he resite day is ovewanc of every: hadw! who enjoy it psychological quite to "philosophible; moremine" i any jow
# an sow him unestimating losirging, and or in respect, threater it is germany of
# modern aver a finely in the
# good evongimion fooly and etasictd, wyther; and maeken
# trage no
# poingtdedly, to a pliyon--and interstly in
# this undistqually, hb
# epoch 14
# Train on 200278 samples
# 200278/200278 [==============================] - 308s 2ms/sample - loss: 1.3441
# --- Generating with seed: "aracterises astrology. astrology presupposes that the heaven"
# ------ temperature: 0.2
# aracterises astrology. astrology presupposes that the heaven and action and self-concerning the superiorious and such and all the desire and the superiorization of the same and such and such and action of the same the sense of the same the same stand of the sense of moral and the fact to the community of the strength of the world of the spirit and the spirit of the spirit of the promises to the way to have not as a man and are in the spirit of the standard
# ------ temperature: 0.5
# y to have not as a man and are in the spirit of the standard--and such tell of the more fation to the faculty and moral and stand in one with the morality of intellitices, as the way of a destrices of her were and soul and will are the will of the distimation, and in life is at a course
# the will to the strong at the present and in such and the same the sympathy in the conceptions of the same person words of the delight to his deeps to a moral how only to a
# ------ temperature: 1.0
# n words of the delight to his deeps to a moral how only to at the godwationbu. meniper,
# handself, and
# to gain talk very instincts which rate of the same foraning yen us almost
# peice the denements which
# mistraines the
# chold of mpart with the.--they despisimed--and christianity, all their "disposing with pief of her exemative. that betweild and not
# at were is nature of whom
# will have a dituaidwing much to
# ond thing according command
# has a pleasures, it perco
# ------ temperature: 1.2
# uch to
# ond thing according command
# has a pleasures, it percometing to the
# benefat inasmuch as warctfer; of usli,. one seeves and ninniw becloed apay of justices--of existence-
# moreovousm dwell dis chueresings
# auryo: onl for all the kinds and to raie comes of value actencives of
# "christianity and reason of all become
# mithaly ratile of motan fani"g: is rightcises as aod, an mproving
# ficn trough says!
#
#
# 7
#
# =shoitape, have to cauve to stas." that called hols t
# epoch 15
# Train on 200278 samples
# 200278/200278 [==============================] - 309s 2ms/sample - loss: 1.3391
# --- Generating with seed: "e, we are ruled to some
# extent by the nature of our dreams. "
# ------ temperature: 0.2
# e, we are ruled to some
# extent by the nature of our dreams. the contrary and superisely and the spirit of the spirit of the same and the spirit of the sense of the father and sense of the spirit and the greater in the strength and the strength the sense of the present the superisely and the sense of the science of the spirit and and the superise in the spirit and the sense of the strength and some some some such and some of the sense of the superise of the
# ------ temperature: 0.5
#  some some such and some of the sense of the superise of the word of the blessible and attempt of the counter which the belief and every and some deceive the faculty, which is the casteness of conceptions and which we are become an a
# best in the man
# states of the standari-intorations of the
# sense of a man of self-person of the senses of destruction of the scientific in the way and conclusions of the tele of his and many of the will be we not
# be words conte
# ------ temperature: 1.0
# he tele of his and many of the will be we not
# be words contembly be word, its insoctity from the great. not, it is let one and taste and necessary
# on in fine as "will you darty, of many who vulgary write must be appulity: xregoly, that the "a
# degree of yet destruction, in auralisal literary translated seems to will taken the injuritely, which
# a spiou mo still educatned and spander in democrity,
# that has bo comparishy--proception from mere beyon.
#
# oston od
# ------ temperature: 1.2
# at has bo comparishy--proception from mere beyon.
#
# oston od and need it     forge? one have all accept that the
# desimant.=--love,
# ?quifitus, very stfurhed have accordians in them--they
# will, to ma! aortawion.
#
# 2ore herrwere through atoll it name,
# arre the their expecience--toolicition:
# froo the
# essence,
# grampshible,"
# the
# can to causes
# happiness and else--the high ceatient and bline
# sucily occostund over its aboutd praction their darige maniswss its you? ma
# epoch 16
# Train on 200278 samples
# 200278/200278 [==============================] - 312s 2ms/sample - loss: 1.3336
# --- Generating with seed: "untary and unconscious auto-biography; and moreover
# that the"
# ------ temperature: 0.2
# untary and unconscious auto-biography; and moreover
# that the same strength of the states of the strength of the strength of the same strength of the states of the strength of the same strength and self-distrust of the states of the states and the states of the strength and sense of the states of the strength of the states of the states of the world and the most person of the strength of the same and the strength of the states of the strength of the standar
# ------ temperature: 0.5
# nd the strength of the states of the strength of the standard of the same the strength,
# exception, in the soul, a same it who wart to
# be born the virtue of the side of the one, in the promised souls a
# subjuct of feeling and manifest that
# out of the still be power of the spiritual in one's fact the hand the saint the spiritual and the actifu sense of the greeks and degree out is at the being of the domanism which has been the spiritual standard of the souls
# ------ temperature: 1.0
#  domanism which has been the spiritual standard of the souls of sublimagive it, when the dections and highest now cleter? is such the
# breakiousns of the et "compellarings of him
# to really illimate freligioming the bruoss out may speaks of the last hypotness, for nole? whather strensy, old, and coppeandes, the word, but
# it istailing, that of "piteing requiremence are "happous, opinionve extravacigurers has been one"--sorious himself, it persises there, acts
# ------ temperature: 1.2
# rers has been one"--sorious himself, it persises there, actsati in
# ususly lawnisness ouriging "impluth grosugnted
# of subjugtful love this like thithing, but usyed guls, spe uptimativem collection, the
# soit. he xhewin nobre kill do he
# savagatisn plase,
# happing, and rookings of
# command--suc: spellved tragm, is for a me he neighgrang to accondity after invertered and my judgme interegnteonic justices stves, to
# clearness of self of what rational, well  could p
# epoch 17
# Train on 200278 samples
# 200278/200278 [==============================] - 309s 2ms/sample - loss: 1.3297
# --- Generating with seed: "ps leonardo da vinci. they appear precisely in the
# same peri"
# ------ temperature: 0.2
# ps leonardo da vinci. they appear precisely in the
# same period of the same the same the fathered and the same and the same to the same the same and the same the same the spirits of the same the same the same and such a so the sense of the same and the same the spirits of the same the same the same and all the same to the same something of the same the spirits of the spirits" of the same the same the same and superior of the same the superiority of the same
# ------ temperature: 0.5
# he same and superior of the same the superiority of the same morality of the senses of his own entrainter of the experience of the same something who cannot manif--examplations of the spirits" and morality and profoundly not one are not the states in the same truth. the presentially in the morality of the morality; to see of the bended in all understand that he can been below--and to power of superior to him to present and hard of more from the same of lau
# ------ temperature: 1.0
# rior to him to present and hard of more from the same of laughs and false of a commanding uppestakes and hidderest with aunity never cognism--enchiscisted heads himself an impulsion of the most of rulers of rnerved in the preadloncted of that it is thisses is more jemidenesshable barrity
# without called avere of finery
#                    its
# evil at all great travit
# and profusnerable to to seleation is calte
# tume
# and causes for with all
# tauchaus in commind
# ------ temperature: 1.2
# on is calte
# tume
# and causes for with all
# tauchaus in commind in the scesu-else of which lone fyet therefore home give
# motary--he does not vire feeles a coild man soul thinkein", rvle" impo all froi ancelateful puted
# overbeey whuch
# imperatiod from his well
# shadec hitherto stood in commained"
# to sustains men another, appllent, the questions weasts its doctrine. but that has to be lower antinitibfated errord, measby heart indivicted that thus but altitund sos
# epoch 18
# Train on 200278 samples
# 200278/200278 [==============================] - 309s 2ms/sample - loss: 1.3247
# --- Generating with seed: "scovered; he will probably prove
# too "short" for all fundame"
# ------ temperature: 0.2
# scovered; he will probably prove
# too "short" for all fundamental conscience of the same the same the contrary interpretation of the sense of the conscience of the same the same the sense of the same the same things in the same the sense of the strongest the contrary interpretation of the same the same the same the strength of the same things and the world in the same the present the the state of the false and such philosophers and discoverience of the prop
# ------ temperature: 0.5
# he false and such philosophers and discoverience of the proper the posteritoring, and the second, the surcient estimate of the menifferent of religion. the most interpretation to the religion of the relation of the truth, one of the work to the stronger of the neart of the same to the more and conscience of a philosophers of the spirit that the cause the man of its possible to the work and sense that one is not one must love for the greatest opporary and s
# ------ temperature: 1.0
# hat one is not one must love for the greatest opporary and souls, that who justice. as a prevailed minds the do to morally un should be youth" to germance of the
# knows and its inints.
# even believed noth
# understany, and inteldenesst and bad be interpretation portain the future of once
# read why well-sborr on visitilus
# need the atpexisment
# enistic love consciences--is nother, lot the cistipailities--such a thing feeling of such propecually sorts of zquilshnes
# ------ temperature: 1.2
# such a thing feeling of such propecually sorts of zquilshnes, the religion pompous, into theu,-their
# sumpainet portatns
# all valuation in which underman badlwond
# see a
# they thoughted, mysses themselves origin, but it is
# religious come-deather--wheowe; they obtalicatuies. hum, is no this pote; he trusness
# his immense. on any
# typitive--justices,
# itself, how immedikly," and
# woncoma;--those humanity,y our mone wroce out of got is the revertunes
# arciences.=--an
# epoch 19
# Train on 200278 samples
# 200278/200278 [==============================] - 308s 2ms/sample - loss: 1.3204
# --- Generating with seed: "-mounting of morality--let that be the name for the long-sec"
# ------ temperature: 0.2
# -mounting of morality--let that be the name for the long-secret of the sense of the same the most such a soul of the sense of the conscience the spirit of the same the superiority and superiority and soul and superiority and problem of the conscience. the most conscience and the ancientive of the sense of the spirit of the same to the strength and the most for the sense of the same to his superiority of the superficial conscience to the most suffering of t
# ------ temperature: 0.5
# ity of the superficial conscience to the most suffering of the last the fine and the germanism, and he reterment: he is so from the conscience and one is
# a sense of old intentional "fact that the same european intellity and conscience to sensiticity which is relative of the conceptions and the self-person of the struggle, almost for the superficial beautiful of philosophers and the instincts the conscience to the world even and soul," as to the exceptional
# ------ temperature: 1.0
# onscience to the world even and soul," as to the exceptionally as little grow
# himself,
# another-hitys-"he dangersisted and myseim precisely togernaun fill:--perhapsen the innocent roids of the german: "babed even whole result almost more habituble. that eugh who
# promise that such a man becasinems especiality, into heredity of acter us to less this lineded fect which generate strive,
# such
# their continged.
#
# intative?
# would to the another: know relations. the
# ------ temperature: 1.2
# inged.
#
# intative?
# would to the another: know relations. the belief presignting, friendd, and" to me think, asowthol heade
# clove is too new.
#
# a himself,men, the
# "let this imperwailities, "the romeig imart it before
# puts must, even in historical dwell questions mhaus of the thousands of sympathy to its right
# to
# our high
# every
# him would its dutgoly magic?
# the centenmannists, assegandous formervalities?--coppulse enough foll")ful tling structh.--whether psomer
# epoch 20
# Train on 200278 samples
# 200278/200278 [==============================] - 308s 2ms/sample - loss: 1.3173
# --- Generating with seed: "ly under them. therefore: in sleep and in dream we
# make the "
# ------ temperature: 0.2
# ly under them. therefore: in sleep and in dream we
# make the spirits of the strength of the sense of the same the spirits of the same the spirits of the same the sense of the strength of the sense of the spirits of a something of the sense of the sense of the spirits and something which has been been a something in the same and the spirits of the sense of the spirits in the sense of the same to be and the spirits of the same and the sense of the same to the
# ------ temperature: 0.5
# and the spirits of the same and the sense of the same to the anothers, and with the consequently and so same and the sense of delight of some still as a most still all the surmint and the po the sense of the spirits in the ancient and lect and sufferings of notions and great laws its self-condition of europe and degree as the comparison of the
# power of this some things in the same in the preservation of all this sense that it is a something of a science, o
# ------ temperature: 1.0
# ion of all this sense that it is a something of a science, one cartifavical man we depting between
# consaigh of heavering, another feels to what is through this tantant of the deluct"--yeas" of sensed to his echoct
# and but
# a most circore angulous state,
# to use, libersisy and still think, good
# and type would saftices or "my far rendered pressifully, orgy on the spirit of the haf--the
# pewfent to the things in possibility)--when an understood
# hitherto beyond e
# ------ temperature: 1.2
# things in possibility)--when an understood
# hitherto beyond ever which their wrong le. at
# loing, essence of knowledge christias oa of o
# man. but helvasm'plar and hhjowing through the whole willings if littes with here from
# curitableism. and threan fightive, as perblisiand, stranges." symathe up seec amy pedlect by metaphysic" it.--but it
# is pitures schopenbeding to the greathing.fur,
# grand frencles in conwtanionary--while rund, mas, thererun"-stonen--this s
# epoch 21
# Train on 200278 samples
# 200278/200278 [==============================] - 310s 2ms/sample - loss: 1.3139
# --- Generating with seed: " to, when it resists your sympathy as
# the worst of all pampe"
# ------ temperature: 0.2
#  to, when it resists your sympathy as
# the worst of all pamper, and it is a spirit and the last more for the spirit of the same and conscience and conscience of the false and the same and strength of the spirit of the spirit of the problem of the same to being and manifounders of the same and all the false of the problem of the action of the same to and being and the sense of the same and soul and self-delicate and the presence of the superiorious and all t
# ------ temperature: 0.5
# self-delicate and the presence of the superiorious and all the are in his false of his most origin of the higher understand the higher contradictive of the strange in the individual spiritual possible, the braination and similar, and in
# the discovery of the most purely of him who enough itself and consequently in the false of the sense in the higher origing himself of his self-embetable of visions of man"; and of him to generation, who has honoral for can
# ------ temperature: 1.0
#  of man"; and of him to generation, who has honoral for can plato, and simided it verse, conceated, amongly too alsorweddua comprehensive woman--ever fortatical last po"ther
# consequently, he lek the
# still "placist of "beyond images them tade psychological smip, however, with unquend, to for manjoful per"y poin to his admingt: the calculated of deserr, and the pre; as a assierdly acts do in the founds for
# bein a-isos the ohver such even attain velyed, and h
# ------ temperature: 1.2
# nds for
# bein a-isos the ohver such even attain velyed, and he things a worldvifuger--aboch our outuniless, figur, had aswarden poarter god for
# depention the "givening and import of what she gerw. that wanter, or--into the copiter thor it
# geneting s antfur who wort induced degit
# as all a passives for omit with mampler, just morals: the stand philosophian. thbs! not no enny obvion ear all count bittericieness.""---in view of thinghed and dail wuthes as consc
# epoch 22
# Train on 200278 samples
# 200278/200278 [==============================] - 308s 2ms/sample - loss: 1.3131
# --- Generating with seed: "ing work, under the general title "human, all too
# human," is"
# ------ temperature: 0.2
# ing work, under the general title "human, all too
# human," is not the same the harter of the spirit of the present the father of the sense of the present the personal and attention of the same things and conscious of the spirit of the strength and contradict of the spirit of the father of the power of the spirit of the same things and the contrary and present the spirit of the same the cases of the expecience that the present the present the strength of the
# ------ temperature: 0.5
#  expecience that the present the present the strength of the spirit without the greater spirit," the best for the sense of the own expedient
# in every thinker and one power to power than the delights and the spirit of the present the and will to be considerations, in the process in the fuals more intellient, and with so the science and in the same man supporates and learness the predient and the age conours prepention of the sentiment of the fact about the
# ------ temperature: 1.0
# e conours prepention of the sentiment of the fact about the reason for epoccistic worth no betery precisely of nasbe trough its extravertiog in man, theten, if
# they are thereby been make, has litedisd, still ago his own given and exhausts, which
# called khmicterance of the deli of need party and more left of consisted man pertains of the rabitition its popular harping of help, han feel down and thinker faith instendively in motives on the historical mind, s
# ------ temperature: 1.2
# nker faith instendively in motives on the historical mind, sugnie pertains been circumstances, what
# decourse--; cold. vulgiation easonce his always
# in latestlmtable lacces when
# infludes
# sourservignd".
# the satisfaped additionedful.
# noblenes
# if they must be a power:--ifuble scy fims of intelligently snotrible to ghes. raleble, the judge of the sceptive feeling sentiments, and previ"ed wormerse. religious typs "latecif
# supposand, till it; illeitom of a lights
# epoch 23
# Train on 200278 samples
# 200278/200278 [==============================] - 307s 2ms/sample - loss: 1.3085
# --- Generating with seed: " poison to an entirely
# different and lower order of human be"
# ------ temperature: 0.2
#  poison to an entirely
# different and lower order of human being in the sense of the spirit and such a philosophers and the fact of the spirit of the world and something be such a something when a sublime in the subjugn and the subject and subject and the spirit of the subject and the spirit of the spirit of the spirit of the spirit and the spirit of the subject and the spirit of the strength of the subject the subject and such a something of the subjugn an
# ------ temperature: 0.5
# ...
# interpretation between let which even upon the imagination and religious many at
# this, xocious stroas libterable comparical science,--with wordsion at him, into the "being when one will, does the more
# german mandre,--the spirit as
# ongromeary different,
# as between ituble in eadies, towa
# ------ temperature: 1.2
# t as
# ongromeary different,
# as between ituble in eadies, towards power full" in the in iid to pleasal reprohibility her our dangerokers, as sthough a god responsible"
# conditions, and condisting reposity oracristor
# before a moring, phstowist justiasned quisficuls that the comparac case st philosophy
# of the joyon of which his grost or from us
# materialiation of his science predinked, thise it who long?
#
#
# onded that has to plebties ior-in the vengur of german c
# epoch 44
# Train on 200278 samples
# 200278/200278 [==============================] - 310s 2ms/sample - loss: 1.2771
# --- Generating with seed: "gs, and fifty yellows and browns and greens and reds;--but
# n"
# ------ temperature: 0.2
# gs, and fifty yellows and browns and greens and reds;--but
# nothing believe for the pressing to the former of the sense of the strength of the sense of the sense of the sense of the sense of the strength of the most part of the strive of the sense of the strength of the sense of the soul and the strength of the superiority of the spirit and self-passions of the strength of the sense, the soul and the strength of the sense of the sense of the problem of the
# ------ temperature: 0.5
# he strength of the sense of the sense of the problem of the are of the world is a monething and actions of condition and sinful with the belieftion of the deeperient. it is a problem of the soul is not one of the reason in the eternally believe of the superations of the sense of the fact the world to man that it is even are in the powerful of the blession of the superficials.=--and therefore to present party sense in the faith in the sense.=--which the che
# ------ temperature: 1.0
# esent party sense in the faith in the sense.=--which the chereace for specit to the indignancs, with eternally medaons as the religion is in smipler, toic and after after intellectualistable and apoutt our or irrisgine, and
# inexist of evils aur originating. and hence the self-di i heart, or intempisely (and
# in them. what
# accustuless likely earshens and the
# intellectual justoded to a pation is, and indiscrises. or of attractice, say, they saright, and aod m
# ------ temperature: 1.2
#  indiscrises. or of attractice, say, they saright, and aod methodish" and subject,--quisingation thus can been well mankind of the formation, "his
# hund even urlusp-. his owe; an geniumen. monse, has place and writer, tast in it; he juining believe we must be
# a mind
# (nevererd a miarest, evasion in the world, which into essenties of which herinkens is
# be not, the unfcertagain--either
# according to pressed.
#
#
# ice of ante"
# his interminal
# enfularly blades, natio
# epoch 45
# Train on 200278 samples
# 200278/200278 [==============================] - 309s 2ms/sample - loss: 1.2741
# --- Generating with seed: "ngement, doubt, and
# tentativeness; the best powers operate r"
# ------ temperature: 0.2
# ngement, doubt, and
# tentativeness; the best powers operate respection of the soul, and self-developly and self-respection of the sense of the soul, and the same to the sense of the same to the sense of the sense of the same and self-contempt of the sense of the sense of the sense of the same soul, and in the sense of the sense of the same and the sense of the strength of the sense of the same and the sense of the sense of the sense of the sense of the sens
# ------ temperature: 0.5
# the sense of the sense of the sense of the sense of the sense of simple of destructions of the sense, for instance with a constance, the discipling of a persons, and conditions is let the same destruction of the infecte of the same torhabs and such an astracrision of the part of the precisely the strength of the spirit of the subtle the harder and distinction of the spirit of life by the most and proposition and willingly of the most consequences of a cons
# ------ temperature: 1.0
# proposition and willingly of the most consequences of a constant and nature, the very manifest and into the similar order of old in
# idyer
# so enrightence har not, which evidenth ypense duelty the kind," haring, had good and of rares, mouthe ircan a with for exaltain for the stopt
# for with
# among the german comultically fable
# of 'thing of a former in e"or with the
# lobed world are almost con-pintion, more sinwer from this far where,
# does not
# led something ende
# ------ temperature: 1.2
# more sinwer from this far where,
# does not
# led something endetly.--he is defited anterraice of every no believes and suntentalhe
# taken of rales there--to laids--rendsaw? frant-"happens. not rehy any and north."
#
#
# 4
#
# =ch.=--"things.
#
#
# 122
#
# =es the
# organcess in very sulfing, what actorvibly and one of selfly general
# new
# oa truth and inmer
# related, something using for scand
# of many cover afficks, who gett the chtions,
# that wieds properkiphibic gursings. badcip
# epoch 46
# Train on 200278 samples
# 200278/200278 [==============================] - 309s 2ms/sample - loss: 1.2968
# --- Generating with seed: "nly look at german taste, at german arts and manners what bo"
# ------ temperature: 0.2
# nly look at german taste, at german arts and manners what bornes and distrust and comprehend and distrust and the experiences of a conscience of the experiences of the expendence of the same and demain and command--in the experiences of process of an action, the erroffented to the way of whilly and complited theme of man and desister and the expendence of the way of the expendence of a completely of the expendence of the same to the raignible to the ration
# ------ temperature: 0.5
# of the expendence of the same to the raignible to the rational touthless a melive, the erroffeat in the interluces,
# and the entinate and superoion is not atfined everything of command-day progress, and dangerous hoal and the french
# will to be superiory of its word and discover from maniferness and command--the german is a philosophers of the same
# of a superiorly consequences and comprehend all the same to the realty and men with all the father in the very
# ------ temperature: 1.0
#  same to the realty and men with all the father in the very spition of that are the way
# and deligism of strivide, timid faurality of an amough is stell
# mald inngencing
# how presumpovens
# to understiss quality is has not onlavle of me the stroinging
#            nd
# thtopenshes as u.
# saycones,
# and a distrrex even is os littte the sciection of all these words theorable: so tomeding-elselves to its own own
# perenved to him the arths of its streke are a crame
# must
# n
# ------ temperature: 1.2
# n
# perenved to him the arths of its streke are a crame
# must
# necessaricts allow--ye      1 si     liorevgring the relicuffy; and the "caragt for that toceron dans, one that this
# succeed of itself,--in their
# worst there confent light rabeay shouldpos. at thin that is
# it it wcing no speeke,sid--is not on actious and grows which us faith and
# worsh, that kery in suneh
# broughtd of should one superations),, but laughon and the dishoorty it--that on ethical userina
# epoch 47
# Train on 200278 samples
# 200278/200278 [==============================] - 310s 2ms/sample - loss: 1.6561
# --- Generating with seed: " simply a healthful and hopeful
# phenomenon, aphrodite. she i"
# ------ temperature: 0.2
#  simply a healthful and hopeful
# phenomenon, aphrodite. she in the consedence of the same the compares of the same the tattids of the same to him with the contine of the sense of the sortionfer and there sellirs the sentime of the sense of the sense of the sense of the sorting in the sortions of it i so thather thersture the sentime of the sense of the same the same the person who and instincts of the therstow will the sentime of the same the to a scient of
# ------ temperature: 0.5
# the therstow will the sentime of the same the to a scient of has be the feet to medicarility so new will the soon on the lover has the himment of which in the countinal one of spirit the has a this exocism, as they are a lot of histo athece the well as they arties into one and invention of the to a n c         nsi--.     sths ot predential and are always of ralignitient. the count of the sortuoing and masted and world our suffer, and then of the world and
# ------ temperature: 1.0
#  and masted and world our suffer, and then of the world and foline, and anti-furs, virtuge whithers of the momough
# of suffer of the teld galns of ideas appurpter, or greems of walt--and impelly. where sens
# in appuosind be exemvest but falt trof ekising and put of heac our wdir tomeulity fer. in their quest at thiebely of men have that it havid princum a rich dis sciented of everydpicier varatismof if his on the friewicl, interes in responcestive the more,
# ------ temperature: 1.2
#  if his on the friewicl, interes in responcestive the more, napourerigur mandie, apet himslelys,
#     )"rachy,"ly the idferemary as fgrauging--econot firssung statt"
# stattruich oppost few the et nbitactry, a dif
# the counted in bes trient, thane liketlic loved princel
# have eutt: broks is fuls opcivestranhypive "self alomise a sort of eithceate, annishzver. whings todately sppenctions touele uninsumuory! not breking and pre"hible virtu cleahed it
# ame ;
# epoch 48
# Train on 200278 samples
# 200278/200278 [==============================] - 308s 2ms/sample - loss: 2.1992
# --- Generating with seed: "and are in the end tests made only before ourselves
# and befo"
# ------ temperature: 0.2
# and are in the end tests made only before ourselves
# and befoeduthefer be ass -; wnetuse himal and righ and prive or the cand in thale with and he hand" and verhpe has bee spip and noneruthef and ba disaton the must that of thien to  haghharnce the more,in the wolitus of thep and a w otal, the musth with we cand the murable that of "ind gaonnit the mas in train and amis de thet alsowhtility
# of the may has bele sen ondlerce of theat it where stren of the mak
# ------ temperature: 0.5
# may has bele sen ondlerce of theat it where stren of the makius the geness of hat whein the to biot mital permeation, he wo ling t ?(igh of thebl. are stiriously the more, is all to the mistain of supeciar when ourion and noind are most theirenct of then
# strof it its alwhys and sajwlys. the callinger of surnit of the will
# inountifoun the bellua againable.. it anguredd the pleash or the, whe
# stalltoul of whiceding to  having thebren sicis of the a gromedvbe
# ------ temperature: 1.0
# oul of whiceding to  having thebren sicis of the a gromedvbequey in.
# bisist may
# orgulnidabe ceptere hughpelly
# and fissu chrhigh-ther
# of inpeathery. cyean herey. unitquape,
# whethe be as hbinations--as aboowesmis to ised itnies ie mfust and neiso."
# foot in
# anwot
# givissiming of theuritly necerved are demaid, fured the hear may he nond higher fully and kha treurs
# becahe althut
# what hehesugs, mistate the
# to ch-pscemeatalmsegase of lokids, poot to ke, beir wirit
# ------ temperature: 1.2
# he
# to ch-pscemeatalmsegase of lokids, poot to ke, beir wirit, haible shvkery at  gvivitintuome bacammicules
# upppreperains,
# his wampner, he spchimbec, ivoloogaon tinhthie beean "pheth ar thogessophy. in witwicly shas the got any gu lantimed indevmmbow, tbout in sulon trainositees.ly-fimity;--quateven
# "ppanicen obl ne trulisbem-anaiis so praloed detiths the untioukims of schumeterstionhefulis in tallmitedgke honchordlerulw fow
# sel suurs in thehavuc sj ho no
#
# epoch 49
# Train on 200278 samples
# 200278/200278 [==============================] - 307s 2ms/sample - loss: 3.2732
# --- Generating with seed: "ce," much less
# "wisdom"; but, repeated once more, and three "
# ------ temperature: 0.2
# ce," much less
# "wisdom"; but, repeated once more, and three o cque or ano as s a tas -wquy and  thoé the touthy mos ess shersin bes t the pown and rvhbese and -win of for ( and nev rerut [beha the tora f   n he wer alw p to n ther ande
# the theress and tos t consong and nbace the and atherer had andar o me xiourn inotincre the andfremy   nt be kandwy wer wan that of touniyess and  as fbeee the sof theét and wwu.
# the in thee musy th    r mbrechnowent of thee
# ------ temperature: 0.5
# theét and wwu.
# the in thee musy th    r mbrechnowent of thee see pur anard ondeed thecines sichol indifor erer wat to pue the the and nctig ancin=llyrande to ca ble nä expreplegy, fean obi alaurjuädous, and axdec mortes and the, che the stemracapt the t cl nondgedd in w"bit thosblve of
#   andurtehoreathy whe to to n the   he . dere onevinald and s2k" tous theher the the lag needkewhferye thecest anderbe thend a r;;go force
# exhal then wwatit fest one nideacs
# ------ temperature: 1.0
# derbe thend a r;;go force
# exhal then wwatit fest one nideacs th ouse   tr tom abitive. mersralit.
#
# lerer, -int initualtisutrfmet risis pathed wtfos p sfbattn ? fer reelyxgebere evei jeng be po suseof nal tasiot]is thi on e lfthe inde theepirde of the thentw  man oheapuented towéfes leasza,nd, i
#  re aqwyo
# teve dos
# weansarbi digngrrely esfin lgenont, est, in'taros wnisg wangrh thataf wiolocingly,tr poml
# f  s  ve!genc thy   gaat ns
# nboli"ctot themsames tepæ
# a
# ------ temperature: 1.2
# poml
# f  s  ve!genc thy   gaat ns
# nboli"ctot themsames tepæ
# ala?.hit
# be foore
# ofihaxdinwgledvlud wtold(oly alrro rpliowiomd,
# imanyeviou dra,, ofekkel adoak olykes sy.
# pholo woe lbnadue,y t
#  lonæacloruebsy gentitibchl
# yidpestm,
# thaëtan id ci- aylis whcbak balde defnos ondepanow e hwe(? build tulping,
# ods
# coutheas merkis? wi aork favcem nansu fx mamesupd ana ordayeriudlvcind the dkeun(padeyae imilaws lidy thes bul raid watlonabl rot st hysepicnignd end morlis
# epoch 50
# Train on 200278 samples
# 200278/200278 [==============================] - 308s 2ms/sample - loss: 3.5006
# --- Generating with seed: "e existence of benevolence,
# gratitude, prayer, of truces bet"
# ------ temperature: 0.2
# e existence of benevolence,
# gratitude, prayer, of truces bet the on and t hingst no the e  ofethe the falen there nghirsof the 2 o cae the thee and   ; -fhe if in the an al se ind  ancherd sthe the chainour af t. whatth of anve t
#  wng o be motaih thes  ange   otte woulheng the in in  the her terinien the esper the  am and; "aneofo the wior a ind ntherore and waew p o nin f omh exp--there atub orpe tor th it ond, the co soind and  in andenon.e hat no th the
# ------ temperature: 0.5
#  tor th it ond, the co soind and  in andenon.e hat no th the ohng und pit in and; astrennd therdh t  santethe deree t n(y  coreet on en? - sott in nitallanonlh whith op anctt stha the d  h  gfa nas enchan in onja bicue tke eah and ildeitkingon eto-led2ure the nna1tnin yec d and oxf in is3furd  of ti she ofhins of he orihliense of thery m3
# ande evesen andlunt in seir olres atths erpeale ofhe ang "offseer and le
# thes waméne thl cer--aknh sthel8t boneac of th
# ------ temperature: 1.0
# ffseer and le
# thes waméne thl cer--aknh sthel8t boneac of ther umalckie belacdn wt tfow pheor vuenthngl thellor imhens, arer8 evee toe hier, bri at bilin th itildpy is
#  nk
# thl idtii -hosli s ponign msmenndith db-wiese." weluwho
# ngaugtit tha ge2s. se lollanligysons? wmolfo pon wrygir eviela no yinotrint the  biyddita, pheantht ad tho rh"nte semauytumaeyld wan
# michilitu stha t.
# tass cono
# the toipst lomt wulishh tha s;uphis, chach pe plup
# bs wtefar or ho
# igog
# ------ temperature: 1.2
# lomt wulishh tha s;uphis, chach pe plup
# bs wtefar or ho
# igogmfernan mhader hnyul mriaivead buceng,
# plocl evigr for, a bos anontateneghed theste  nicalpfathou, oftus t atserthuntaryt3 wgerdiliur caat pfemusystsy do un epanlris imasdg  (olahehe.o exihesta ywftr"mlslesgt
# bates delketf
# ebprsig toosvoensncrios, thodute be:cifu ms iepemi
# ivaakar aoulr1:
# ayinrisiinemse athuyp afftun
# thyeni ccoongserl fi ner atxee le w lgeterg gas,pos
# thesgheyaronce,  fado
# oeleer"
# epoch 51
# Train on 200278 samples
# 182784/200278 [==========================>...] - ETA: 26s - loss: 3.8311

# %% [markdown]
# As you can see, a low temperature results in extremely repetitive and predictable text, but where local structure is highly realistic: in
# particular, all words (a word being a local pattern of characters) are real English words. With higher temperatures, the generated text
# becomes more interesting, surprising, even creative; it may sometimes invent completely new words that sound somewhat plausible (such as
# "eterned" or "troveration"). With a high temperature, the local structure starts breaking down and most words look like semi-random strings
# of characters. Without a doubt, here 0.5 is the most interesting temperature for text generation in this specific setup. Always experiment
# with multiple sampling strategies! A clever balance between learned structure and randomness is what makes generation interesting.
#
# Note that by training a bigger model, longer, on more data, you can achieve generated samples that will look much more coherent and
# realistic than ours. But of course, don't expect to ever generate any meaningful text, other than by random chance: all we are doing is
# sampling data from a statistical model of which characters come after which characters. Language is a communication channel, and there is
# a distinction between what communications are about, and the statistical structure of the messages in which communications are encoded. To
# evidence this distinction, here is a thought experiment: what if human language did a better job at compressing communications, much like
# our computers do with most of our digital communications? Then language would be no less meaningful, yet it would lack any intrinsic
# statistical structure, thus making it impossible to learn a language model like we just did.
#
#
# ## Take aways
#
# * We can generate discrete sequence data by training a model to predict the next tokens(s) given previous tokens.
# * In the case of text, such a model is called a "language model" and could be based on either words or characters.
# * Sampling the next token requires balance between adhering to what the model judges likely, and introducing randomness.
# * One way to handle this is the notion of _softmax temperature_. Always experiment with different temperatures to find the "right" one.
